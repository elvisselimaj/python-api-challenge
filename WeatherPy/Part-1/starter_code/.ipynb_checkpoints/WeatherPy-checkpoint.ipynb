# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
import elvis_api_keys

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 620

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# OpenWeatherMap API Key
key = elvis_api_keys.api_key

# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=" + key

query_url = url + '&q='

cityweather = []
lat = []
temp = []
windspeed = []
cloudiness = []
humidity = [] 
id_city = []


# Loop through the list of cities and perform a request for data on each
for city in cities:
    response = requests.get(query_url + city).json()
    try:
        lat.append(response['coord']['lat'])
        temp.append(response['main']['temp_max'])
        windspeed.append(response['wind']['speed'])
        humidity.append(response['main']['humidity'])
        cloudiness.append(response['clouds']['all'])
        id_city.append(response['id'])
        cityweather.append(city)
        print(f"The city being processed is: {city} | {response['id']}")
    except:
        pass
# Out:
# The city being processed is: castro | 3896218
# The city being processed is: bhuj | 1275812
# The city being processed is: kapaa | 5848280
# The city being processed is: arman | 2127060
# The city being processed is: mahebourg | 934322
# The city being processed is: am timan | 245338
# The city being processed is: isangel | 2136825
# The city being processed is: bambous virieux | 1106677
# The city being processed is: esperance | 2071860
# The city being processed is: mar del plata | 3863379
# The city being processed is: college | 5859699
# The city being processed is: rikitea | 4030556
# The city being processed is: pevek | 2122090
# The city being processed is: bethel | 5880568
# The city being processed is: vao | 588365
# The city being processed is: marystown | 6067472
# The city being processed is: punta arenas | 3874787
# The city being processed is: san policarpo | 1688696
# The city being processed is: chokurdakh | 2126123
# The city being processed is: hobart | 2163355
# The city being processed is: hilo | 5855927
# The city being processed is: sitka | 4267710
# The city being processed is: albany | 5106834
# The city being processed is: sri aman | 1735799
# The city being processed is: raudeberg | 3146487
# The city being processed is: manzhouli | 2035836
# The city being processed is: ilulissat | 3423146
# The city being processed is: buala | 2109528
# The city being processed is: tilichiki | 2120591
# The city being processed is: ushuaia | 3833367
# The city being processed is: tiksi | 2015306
# The city being processed is: lagoa | 2267254
# The city being processed is: mayumba | 2399001
# The city being processed is: hermanus | 3366880
# The city being processed is: port alfred | 964432
# The city being processed is: cidreira | 3466165
# The city being processed is: butaritari | 2110227
# The city being processed is: mataura | 6201424
# The city being processed is: tahe | 2034615
# The city being processed is: cape town | 3369157
# The city being processed is: escanaba | 4992232
# The city being processed is: faya | 110690
# The city being processed is: new norfolk | 2155415
# The city being processed is: kingston | 3489854
# The city being processed is: arraial do cabo | 3471451
# The city being processed is: touros | 3386213
# The city being processed is: dombarovskiy | 565407
# The city being processed is: baherden | 162158
# The city being processed is: novichikha | 1497220
# The city being processed is: baruun-urt | 2032614
# The city being processed is: mount isa | 2065594
# The city being processed is: port lincoln | 2063036
# The city being processed is: sobolevo | 525426
# The city being processed is: minusinsk | 1498693
# The city being processed is: port augusta | 2063056
# The city being processed is: souillac | 3026644
# The city being processed is: vilcun | 3868210
# The city being processed is: vostok | 2013279
# The city being processed is: muskegon | 5003132
# The city being processed is: port keats | 2063039
# The city being processed is: saint-pierre | 2995603
# The city being processed is: iqaluit | 5983720
# The city being processed is: jamestown | 2069194
# The city being processed is: syracuse | 5140405
# The city being processed is: araouane | 2460954
# The city being processed is: khatanga | 2022572
# The city being processed is: pangnirtung | 6096551
# The city being processed is: kichera | 2022129
# The city being processed is: alanya | 324190
# The city being processed is: olavarria | 3842670
# The city being processed is: hasaki | 2112802
# The city being processed is: santa vitoria do palmar | 3449747
# The city being processed is: lata | 1253628
# The city being processed is: mahibadhoo | 1337605
# The city being processed is: san patricio | 3437029
# The city being processed is: tangjiazhuang | 1783626
# The city being processed is: faanui | 4034551
# The city being processed is: yelizovo | 2119538
# The city being processed is: meridian | 5600685
# The city being processed is: marihatag | 1700933
# The city being processed is: atasu | 1526041
# The city being processed is: yar-sale | 1486321
# The city being processed is: leningradskiy | 2123814
# The city being processed is: tautira | 4033557
# The city being processed is: gumdag | 161943
# The city being processed is: saskylakh | 2017155
# The city being processed is: lamu | 1791522
# The city being processed is: victoria | 1733782
# The city being processed is: busselton | 2075265
# The city being processed is: ashqelon | 295620
# The city being processed is: nikolskoye | 546105
# The city being processed is: komsomolskiy | 1486910
# The city being processed is: callaway | 5024237
# The city being processed is: atuona | 4020109
# The city being processed is: longyearbyen | 2729907
# The city being processed is: turochak | 1488920
# The city being processed is: huilong | 1784131
# The city being processed is: hofn | 2630299
# The city being processed is: pavilosta | 456827
# The city being processed is: chuy | 3443061
# The city being processed is: bluff | 2175403
# The city being processed is: bereda | 3105522
# The city being processed is: shasta lake | 5571109
# The city being processed is: gangakher | 1271688
# The city being processed is: dakar | 2253354
# The city being processed is: vaini | 1273574
# The city being processed is: yellowknife | 6185377
# The city being processed is: novyy urengoy | 1496511
# The city being processed is: grand-lahou | 2288105
# The city being processed is: saint-philippe | 6138908
# The city being processed is: flinders | 6255012
# The city being processed is: puerto escondido | 3520994
# The city being processed is: lorengau | 2092164
# The city being processed is: terney | 2015352
# The city being processed is: porto novo | 6322184
# The city being processed is: la ronge | 6050066
# The city being processed is: namatanai | 2090021
# The city being processed is: narsaq | 3421719
# The city being processed is: oktyabrskoye | 1511846
# The city being processed is: tasiilaq | 3424607
# The city being processed is: catuday | 1717787
# The city being processed is: itarema | 3393692
# The city being processed is: kahului | 5847411
# The city being processed is: sao filipe | 3374210
# The city being processed is: khani | 610864
# The city being processed is: mehamn | 778707
# The city being processed is: kincardine | 5992144
# The city being processed is: shubarshi | 608270
# The city being processed is: youhao | 2033301
# The city being processed is: rapid city | 5768233
# The city being processed is: rio tuba | 1691703
# The city being processed is: challapata | 3921355
# The city being processed is: magadan | 2123628
# The city being processed is: nalut | 2214433
# The city being processed is: cuamba | 1047660
# The city being processed is: verkhnyaya inta | 1487332
# The city being processed is: lodwar | 189280
# The city being processed is: amapa | 3603330
# The city being processed is: wiarton | 6186122
# The city being processed is: roma | 6539761
# The city being processed is: nuuk | 3421319
# The city being processed is: tecoanapa | 3532499
# The city being processed is: kapuskasing | 5989403
# The city being processed is: lasa | 146639
# The city being processed is: brae | 2654970
# The city being processed is: bambanglipuro | 1650434
# The city being processed is: klaksvik | 2618795
# The city being processed is: shonguy | 493795
# The city being processed is: lebu | 344979
# The city being processed is: puerto ayora | 3652764
# The city being processed is: ledyard | 4839420
# The city being processed is: portland | 4975802
# The city being processed is: anadyr | 2127202
# The city being processed is: micheweni | 153955
# The city being processed is: cabo san lucas | 3985710
# The city being processed is: diego de almagro | 3892454
# The city being processed is: dikson | 1507390
# The city being processed is: leshukonskoye | 535839
# The city being processed is: barrow | 3833859
# The city being processed is: qaanaaq | 3831208
# The city being processed is: airai | 1651810
# The city being processed is: thompson | 6165406
# The city being processed is: san andres | 1690438
# The city being processed is: cabra | 2520645
# The city being processed is: nelson bay | 2155562
# The city being processed is: kieta | 2094027
# The city being processed is: ribeira grande | 3372707
# The city being processed is: provideniya | 4031574
# The city being processed is: tuatapere | 2180815
# The city being processed is: prieska | 964090
# The city being processed is: jutai | 3388869
# The city being processed is: norman wells | 6089245
# The city being processed is: zemio | 235826
# The city being processed is: port elizabeth | 4501427
# The city being processed is: carnarvon | 1014034
# The city being processed is: aras | 3129839
# The city being processed is: camacari | 3468031
# The city being processed is: henties bay | 3356832
# The city being processed is: balkhash | 1525798
# The city being processed is: tagusao | 1684245
# The city being processed is: alyangula | 2079582
# The city being processed is: balad | 1646170
# The city being processed is: morro bay | 5374920
# The city being processed is: dekernes | 358172
# The city being processed is: kavaratti | 1267390
# The city being processed is: klyuchi | 1503153
# The city being processed is: cherskiy | 2126199
# The city being processed is: georgetown | 3378644
# The city being processed is: kodiak | 4407665
# The city being processed is: walvis bay | 3359638
# The city being processed is: sohag | 347796
# The city being processed is: tateyama | 1849876
# The city being processed is: inongo | 2315417
# The city being processed is: ust-maya | 2013918
# The city being processed is: zyryanka | 2119283
# The city being processed is: gyomaendrod | 720364
# The city being processed is: aquiraz | 3407407
# The city being processed is: wilmington | 4145381
# The city being processed is: forte dei marmi | 3176674
# The city being processed is: chumikan | 2025256
# The city being processed is: fortuna foothills | 5295143
# The city being processed is: le port | 3036965
# The city being processed is: petropavlovsk-kamchatskiy | 2122104
# The city being processed is: inuvik | 5983607
# The city being processed is: lae | 2092740
# The city being processed is: moron | 3720455
# The city being processed is: formosa do rio preto | 3463124
# The city being processed is: ust-kuyga | 2013921
# The city being processed is: xiaoweizhai | 1789945
# The city being processed is: ewa beach | 5855051
# The city being processed is: ulladulla | 2145554
# The city being processed is: inta | 1505579
# The city being processed is: livingstonia | 927856
# The city being processed is: balabac | 1728675
# The city being processed is: puerto carreno | 3671519
# The city being processed is: banposh | 1277247
# The city being processed is: fort nelson | 5955902
# The city being processed is: carutapera | 3402648
# The city being processed is: metu | 330764
# The city being processed is: havelock | 4470244
# The city being processed is: nantucket | 4944903
# The city being processed is: chingirlau | 610091
# The city being processed is: port-cartier | 6111696
# The city being processed is: tuktoyaktuk | 6170031
# The city being processed is: harboore | 2620767
# The city being processed is: berlevag | 780687
# The city being processed is: luderitz | 3355672
# The city being processed is: cayenne | 3382160
# The city being processed is: aykhal | 2027296
# The city being processed is: adrar | 2508813
# The city being processed is: garbolovo | 561999
# The city being processed is: blagoyevo | 576093
# The city being processed is: bulgan | 2032201
# The city being processed is: houma | 1784874
# The city being processed is: powell river | 6112608
# The city being processed is: emerald | 2167426
# The city being processed is: severo-kurilsk | 2121385
# The city being processed is: salalah | 286621
# The city being processed is: broome | 2656067
# The city being processed is: bouca | 2387890
# The city being processed is: bredasdorp | 1015776
# The city being processed is: grindavik | 3416888
# The city being processed is: tual | 1623197
# The city being processed is: hualmay | 3939761
# The city being processed is: dzerzhinsk | 563708
# The city being processed is: port macquarie | 2152659
# The city being processed is: palmer | 2067070
# The city being processed is: ponta do sol | 3453439
# The city being processed is: haines junction | 5969025
# The city being processed is: kruisfontein | 986717
# The city being processed is: nizwa | 286987
# The city being processed is: fergus falls | 5026416
# The city being processed is: bobcaygeon | 8125787
# The city being processed is: kombissiri | 2359227
# The city being processed is: ketchikan | 5554428
# The city being processed is: malartic | 6064704
# The city being processed is: hithadhoo | 1282256
# The city being processed is: kaeo | 2189343
# The city being processed is: port hedland | 2063042
# The city being processed is: port hardy | 6111862
# The city being processed is: beloha | 1067565
# The city being processed is: zapolyarnyy | 464790
# The city being processed is: hoquiam | 5797693
# The city being processed is: tevriz | 1489661
# The city being processed is: east london | 1006984
# The city being processed is: maragogi | 3395458
# The city being processed is: charyshskoye | 1508427
# The city being processed is: abapo | 3924668
# The city being processed is: thinadhoo | 1337610
# The city being processed is: fomboni | 921889
# The city being processed is: katangli | 2122783
# The city being processed is: nalvo | 7521301
# The city being processed is: shingu | 1847947
# The city being processed is: gueugnon | 3014334
# The city being processed is: vanimo | 2084442
# The city being processed is: kholodnyy | 2124611
# The city being processed is: torbay | 6167817
# The city being processed is: la merced | 3687951
# The city being processed is: chicama | 3698359
# The city being processed is: taseyevo | 1490058
# The city being processed is: coos bay | 5720495
# The city being processed is: alenquer | 3407980
# The city being processed is: pangai | 4032369
# The city being processed is: zhigansk | 2012530
# The city being processed is: miyako | 1848087
# The city being processed is: pisco | 3932145
# The city being processed is: ternate | 1682474
# The city being processed is: tezu | 1254709
# The city being processed is: alofi | 4036284
# The city being processed is: antalaha | 1071296
# The city being processed is: northam | 2064550
# The city being processed is: sabang | 1726279
# The city being processed is: yumen | 1528998
# The city being processed is: havoysund | 779622
# The city being processed is: valentin gomez farias | 4011743
# The city being processed is: dingle | 1714733
# The city being processed is: khargone | 1266928
# The city being processed is: comarapa | 3919703
# The city being processed is: sept-iles | 6144312
# The city being processed is: buritizeiro | 3468720
# The city being processed is: grand gaube | 934479
# The city being processed is: nouadhibou | 2377457
# The city being processed is: buraydah | 107304
# The city being processed is: vila franca do campo | 3372472
# The city being processed is: hovd | 7626384
# The city being processed is: awbari | 2219235
# The city being processed is: port moresby | 2088122
# The city being processed is: novobirilyussy | 1508260
# The city being processed is: kavieng | 2094342
# The city being processed is: kaitangata | 2208248
# The city being processed is: saldanha | 2737599
# The city being processed is: guerrero negro | 4021858
# The city being processed is: bang yai | 1619198
# The city being processed is: parana | 3663516
# The city being processed is: mabaruma | 3377301
# The city being processed is: ocos | 3592086
# The city being processed is: ossora | 2122389
# The city being processed is: la ferte-bernard | 3009494
# The city being processed is: najran | 103630
# The city being processed is: upernavik | 3418910
# The city being processed is: turukhansk | 1488903
# The city being processed is: umm kaddadah | 364933
# The city being processed is: wenatchee | 5815342
# The city being processed is: daru | 2098329
# The city being processed is: clyde | 2192264
# The city being processed is: toora-khem | 1489401
# The city being processed is: carberry | 5916706
# The city being processed is: prabumulih | 1631393
# The city being processed is: fallon | 5681948
# The city being processed is: thai binh | 1566346
# The city being processed is: bathsheba | 3374083
# The city being processed is: antofagasta | 3899539
# The city being processed is: praia da vitoria | 3372760
# The city being processed is: dax | 3021670
# The city being processed is: dudinka | 1507116
# The city being processed is: belmonte | 8010472
# The city being processed is: okato | 2185763
# The city being processed is: husavik | 5961417
# The city being processed is: alto araguaia | 3472473
# The city being processed is: lodhran | 1171965
# The city being processed is: lavrentiya | 4031637
# The city being processed is: clyde river | 5924351
# The city being processed is: bolkhov | 575364
# The city being processed is: karpogory | 552256
# The city being processed is: kuopio | 650225
# The city being processed is: biak | 1637001
# The city being processed is: axim | 2303611
# The city being processed is: saint-augustin | 6138501
# The city being processed is: bonfim | 3379316
# The city being processed is: rodez | 2983154
# The city being processed is: plettenberg bay | 964712
# The city being processed is: constitucion | 4011743
# The city being processed is: guadalupe y calvo | 4005370
# The city being processed is: san quintin | 1688687
# The city being processed is: timon | 3386361
# The city being processed is: richards bay | 962367
# The city being processed is: kiama | 2161515
# The city being processed is: kindu | 212902
# The city being processed is: soyo | 2236967
# The city being processed is: yerbogachen | 2012956
# The city being processed is: avarua | 4035715
# The city being processed is: kualakapuas | 1639304
# The city being processed is: kamenka | 618453
# The city being processed is: kholtoson | 2022369
# The city being processed is: otane | 2185329
# The city being processed is: sapouy | 2355869
# The city being processed is: san cristobal | 3609418
# The city being processed is: erenhot | 2037485
# The city being processed is: monte alegre | 3394605
# The city being processed is: khuzhir | 2022143
# The city being processed is: nanortalik | 3421765
# The city being processed is: san pedro | 3428576
# The city being processed is: bandarbeyla | 64814
# The city being processed is: trujillo | 3625979
# The city being processed is: anchorage | 5879400
# The city being processed is: morag | 3091462
# The city being processed is: laguna | 3581398
# The city being processed is: macamic | 6062563
# The city being processed is: sandwick | 2640416
# The city being processed is: fortuna | 5563839
# The city being processed is: korcula | 3197710
# The city being processed is: vestnes | 3345453
# The city being processed is: ahipara | 2194098
# The city being processed is: virginia beach | 4791259
# The city being processed is: perth | 2063523
# The city being processed is: zandvoort | 2744042
# The city being processed is: erdenet | 2031405
# The city being processed is: lunca de sus | 674413
# The city being processed is: santa vitoria | 3662927
# The city being processed is: cockburn town | 3576994
# The city being processed is: gualaceo | 3657670
# The city being processed is: meghri | 174823
# The city being processed is: el arenal | 4011119
# The city being processed is: gandiaye | 2251688
# The city being processed is: matehuala | 3996387
# The city being processed is: birobidzhan | 2026643
# The city being processed is: maturin | 3778045
# The city being processed is: honjo | 2112569
# The city being processed is: senanga | 898947
# The city being processed is: belyy yar | 1510377
# The city being processed is: igrim | 1505965
# The city being processed is: les cayes | 3728097
# The city being processed is: mauriti | 3395058
# The city being processed is: cabedelo | 3404558
# The city being processed is: sao joao da barra | 3448903
# The city being processed is: dunedin | 2191562
# The city being processed is: mackenzie | 6063191
# The city being processed is: dalvik | 2702977
# The city being processed is: salym | 1493162
# The city being processed is: nome | 4732862
# The city being processed is: apatou | 3382527
# The city being processed is: nouakchott | 2377450
# The city being processed is: ostrovnoy | 556268
# The city being processed is: geraldton | 5960603
# The city being processed is: general pico | 3855075
# The city being processed is: itacoatiara | 3397893
# The city being processed is: honiara | 2108502
# The city being processed is: aklavik | 5882953
# The city being processed is: khudumelapye | 933562
# The city being processed is: marsa matruh | 352733
# The city being processed is: polohy | 696677
# The city being processed is: biltine | 244878
# The city being processed is: atikokan | 5888001
# The city being processed is: kaka | 161901
# The city being processed is: concepcion del oro | 4013039
# The city being processed is: salta | 3838233
# The city being processed is: uyuni | 3901903
# The city being processed is: whithorn | 3491102
# The city being processed is: tamandare | 3661980
# The city being processed is: novikovo | 487928
# The city being processed is: naze | 2337542
# The city being processed is: ambon | 3037899
# The city being processed is: iracoubo | 3381428
# The city being processed is: lompoc | 5367788
# The city being processed is: wanning | 3220813
# The city being processed is: ca mau | 1586443
# The city being processed is: alpinopolis | 3472507
# The city being processed is: talnakh | 1490256
# The city being processed is: acajutla | 3587498
# The city being processed is: camopi | 3382226
# The city being processed is: dobris | 3077024
# The city being processed is: manokwari | 1636308
# The city being processed is: opuwo | 3354077
# The city being processed is: sorland | 3137469
# The city being processed is: berdigestyakh | 2026861
# The city being processed is: pingliang | 1798760
# The city being processed is: labuhan | 1641899
# The city being processed is: medea | 2488835
# The city being processed is: aswan | 359792
# The city being processed is: tura | 2014833
# The city being processed is: fujin | 2037375
# The city being processed is: ostersund | 2685750
# The city being processed is: santa marinella | 3167520
# The city being processed is: khanpur | 1174167
# The city being processed is: mwinilunga | 902620
# The city being processed is: marietta | 4207783
# The city being processed is: pipri | 1258207
# The city being processed is: jandayan | 1710303
# The city being processed is: tsaghkaber | 616159
# The city being processed is: margate | 2158744
# The city being processed is: bonthe | 2409914
# The city being processed is: tungor | 2120400
# The city being processed is: levokumka | 535440
# The city being processed is: mingguang | 1800519
# The city being processed is: paime | 3674121
# The city being processed is: jieshi | 1805857
# The city being processed is: srednekolymsk | 2121025
# The city being processed is: newport | 2641598
# The city being processed is: lumby | 6061958
# The city being processed is: san ramon | 3616584
# The city being processed is: mayo | 6068416
# The city being processed is: banepa | 1283679
# The city being processed is: katsuura | 1865309
# The city being processed is: waingapu | 1622318
# The city being processed is: alexandria | 686502
# The city being processed is: santa maria | 3462672
# The city being processed is: orlik | 3102488
# The city being processed is: cairo | 360630
# The city being processed is: codrington | 2160063
# The city being processed is: can tho | 1586203
# The city being processed is: aljezur | 2271968
# The city being processed is: jalingo | 2351027
# The city being processed is: hamilton | 5969785
# The city being processed is: pasighat | 1260206
# The city being processed is: adeje | 2319133
# The city being processed is: samarai | 2132606
# The city being processed is: jacareacanga | 3397763
# The city being processed is: voyvozh | 471308
# The city being processed is: sistranda | 3139597
# The city being processed is: rodrigues alves | 3665210
# The city being processed is: mahajanga | 1062663
# The city being processed is: cap malheureux | 934649
# The city being processed is: rabat | 2538474
# The city being processed is: barreirinhas | 3406196
# The city being processed is: muzhi | 1498161
# The city being processed is: auray | 3036059
# The city being processed is: coquimbo | 3893629
# The city being processed is: saint george | 262462
# The city being processed is: praya | 1630662
# The city being processed is: ahuimanu | 5856516
# The city being processed is: auckland | 2193733
# The city being processed is: murgud | 1262435
# The city being processed is: inirida | 3671450
# The city being processed is: fairview | 5951036
# The city being processed is: bulnes | 3897724
# The city being processed is: tshikapa | 204953
# The city being processed is: madimba | 2221046
# The city being processed is: nara | 1855612
# The city being processed is: toamasina | 1053384
# The city being processed is: porto murtinho | 3452712
# The city being processed is: maralal | 187725
# The city being processed is: santa rosa de copan | 3601494
# The city being processed is: sulangan | 1685422
# The city being processed is: ginir | 336454
# The city being processed is: bud | 7626370
# The city being processed is: kupang | 2057087
# The city being processed is: maniitsoq | 3421982
# The city being processed is: matti | 1700240
# The city being processed is: brigantine | 4500920
# The city being processed is: mbandaka | 2312895
# The city being processed is: show low | 5314245
# The city being processed is: qasigiannguit | 3420768
# The city being processed is: damietta | 358048
# The city being processed is: karratha | 6620339
# The city being processed is: port blair | 1259385
# The city being processed is: belem | 3664716
# The city being processed is: kisangani | 212730
# The city being processed is: noumea | 2139521
# The city being processed is: chernyy yar | 518909
# The city being processed is: vestmannaeyjar | 3412093
# The city being processed is: kangaatsiaq | 3422683
# The city being processed is: ilebo | 215976
# The city being processed is: fairmont | 5068953
# The city being processed is: qaqortoq | 3420846
# The city being processed is: kutum | 371745
# The city being processed is: avallon | 3035768
# The city being processed is: morondava | 1058381
# The city being processed is: trofors | 3133983
# The city being processed is: egvekinot | 4031742
# The city being processed is: bat khela | 1183090
# The city being processed is: aksarka | 1512019
# The city being processed is: saint anthony | 5606187
# The city being processed is: barcelos | 3665098
# The city being processed is: selma | 4089114
# The city being processed is: manjacaze | 1040938
# The city being processed is: muisne | 3653967
# The city being processed is: bintulu | 1737486
# The city being processed is: sandpoint | 5606401
# The city being processed is: yaan | 2338660
# The city being processed is: serpa | 2263049
# The city being processed is: makakilo city | 5850554
# The city being processed is: los llanos de aridane | 2514651

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_dict = {
    "city": cityweather,
    "lat": lat,
    "temp_max": temp,
    "windspeed": windspeed,
    "cloudiness": cloudiness,
    "humidity": humidity 
}
weather_data = pd.DataFrame(weather_dict)
weather_data.head()
# Out:
#         city    lat  temp_max  windspeed  cloudiness  humidity
# 0     castro -42.48     53.60      12.75          75        71
# 1       bhuj  23.25     79.02       6.24          64        70
# 2      kapaa  22.08     80.60       6.93          20        83
# 3      arman  59.70     33.67      20.71         100        63
# 4  mahebourg -20.41     73.40       3.36          20        88

# %%
# Print the city count to confirm sufficient count
weather_data.count()
# Out:
# city          552
# lat           552
# temp_max      552
# windspeed     552
# cloudiness    552
# humidity      552
# dtype: int64

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["lat"], weather_data["temp_max"], marker="o")

# Incorporate the other graph properties
plt.title("Max Temperature vs City Latitude")
plt.ylabel("Max Temperature (F)")
plt.xlabel(r"Latitude($^\circ$)")
plt.grid(True)

# Save the figure
plt.savefig("../Images/Temperature_Latitude_Plot.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["lat"], weather_data["humidity"], marker="o")

# Incorporate the other graph properties
plt.title("Humidity vs City Latitude")
plt.ylabel("Humidity (%)")
plt.xlabel(r"Latitude($^\circ$)")
plt.grid(True)

# Save the figure
plt.savefig("../Images/Humidity_Latitude_Plot.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["lat"], weather_data["cloudiness"], marker="o")

# Incorporate the other graph properties
plt.title("Cloudiness vs City Latitude")
plt.ylabel("Cloudiness (%)")
plt.xlabel(r"Latitude($^\circ$)")
plt.grid(True)

# Save the figure
plt.savefig("../Images/Cloudiness_Latitude_Plot.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["lat"], weather_data["windspeed"], marker="o")

# Incorporate the other graph properties
plt.title("Windspeed vs City Latitude")
plt.ylabel("Windspeed (mph)")
plt.xlabel(r"Latitude($^\circ$)")
plt.grid(True)

# Save the figure
plt.savefig("../Images/Windspeed_Latitude_Plot.png")

# Show plot
plt.show()

# %%
weather_data.to_csv('elvis_WeatherPy_.csv')
